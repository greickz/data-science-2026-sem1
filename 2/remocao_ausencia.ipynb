# %%
import pandas

data_frame = pandas.read_excel('dados_ausentes.xlsx')
print(data_frame)
# Out:
#        Nome  Idade          Cidade  Sálario
# 0      João   28.0       São Paulo   3500.0
# 1     Maria    NaN  Rio de Janeiro   4500.0
# 2      José   35.0             NaN      NaN
# 3       Ana   22.0        Salvador   5000.0
# 4     Pedro    NaN    Porto Alegre   4800.0
# 5  Vinícius   17.0       são Paulo   3410.0
# 6    Mateus   18.0        curitiba   3500.0
# 7       Ana   22.0        Salvador   5000.0

# %%
print(data_frame.isnull())
# Out:
#     Nome  Idade  Cidade  Sálario
# 0  False  False   False    False
# 1  False   True   False    False
# 2  False  False    True     True
# 3  False  False   False    False
# 4  False   True   False    False
# 5  False  False   False    False
# 6  False  False   False    False
# 7  False  False   False    False
