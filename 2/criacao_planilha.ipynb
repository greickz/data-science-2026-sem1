# %%
import pandas
import numpy 

# Criar um dataframe com alguns dados faltando, esse passo é somente para aprender na realidade a planilaha ja existira
data = {
    'Nome': ['João', 'Maria','José','Ana','Pedro'],
    'Idade': int[28, numpy.nan, 35, 22, numpy.nan], # numpy.nan é para dizer que aquele espaço será vazio
    'Cidade': ['São Paulo', 'Rio de Janeiro',numpy.nan,'Salvador','Porto Alegre'],
    'Sálario':[3500,4500,numpy.nan,5000,4800]
}

data_frame = pandas.DataFrame(data)

print(data_frame)
# Out:
#     Nome  Idade          Cidade  Sálario
# 0   João   28.0       São Paulo   3500.0
# 1  Maria    NaN  Rio de Janeiro   4500.0
# 2   José   35.0             NaN      NaN
# 3    Ana   22.0        Salvador   5000.0
# 4  Pedro    NaN    Porto Alegre   4800.0
