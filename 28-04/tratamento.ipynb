# %%
import pandas as pd
df = pd.read_excel("imoveis_sao_caetano.xlsx")
print(df)

# %%
# Captalize() e Strip()

df[""]=df[""].str.capitalize()
df[""]=df[""].str.strip()

# %%
texto = df.select_dtypes(include=['object'])
valores = df.select_dtypes(include=['number'])
