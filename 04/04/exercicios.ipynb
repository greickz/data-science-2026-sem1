# %% [markdown]
# Exercicio 1

# %%
# Exercício: Carregar um arquivo e exibir as primeiras 5 linhas.

import pandas 
data_frame = pandas.read_excel('Data_frame.xlsx')
print(data_frame.head(5))
# Out:
#     Nome  Idade          Cidade  Salário
# 0   João   28.0       São Paulo   3500.0
# 1  Maria    NaN  Rio de Janeiro   4500.0
# 2   José   35.0             NaN      NaN
# 3    Ana   22.0        Salvador   5000.0
# 4  Pedro    NaN    Porto Alegre   4800.0

# %% [markdown]
# Exercicio 2

# %%
# Exercício: Verificar se há valores NaN nas colunas do DataFrame.

data_frame['Idade'].fillna(data_frame['Idade'].mean(), inplace = True) # mean faz a média
print(data_frame)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria   27.0  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro   27.0    Porto Alegre   4800.0
# 5      Ana   22.0        Salvador   5000.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0
# C:\Users\47377942878\AppData\Local\Temp\ipykernel_72496\2658996083.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %% [markdown]
# Exercicio 3

# %%
# Exercício: Substituir os valores NaN de uma coluna por 0.

data_frame['Salário'].fillna(0, inplace = True) 
print(data_frame)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria   25.0  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      0.0
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro   25.0    Porto Alegre   4800.0
# 5      Ana   22.0        Salvador   5000.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0
# C:\Users\47377942878\AppData\Local\Temp\ipykernel_72496\1280273328.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %% [markdown]
# Exercicio 4

# %%
data_frame['Idade'].fillna(data_frame['Idade'].mean(), inplace = True) # mean faz a média
print(data_frame)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria   27.0  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro   27.0    Porto Alegre   4800.0
# 5      Ana   22.0        Salvador   5000.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0
# C:\Users\47377942878\AppData\Local\Temp\ipykernel_72496\2584518250.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %% [markdown]
# Exercicio 5

# %%
df_sem_nan = data_frame.dropna()
print(df_sem_nan)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria   25.0  Rio de Janeiro   4500.0
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro   25.0    Porto Alegre   4800.0
# 5      Ana   22.0        Salvador   5000.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0

# %% [markdown]
# Exercicio 6

# %%
df_sem_nan = data_frame.dropna(subset=['Idade'])
print(df_sem_nan)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria   25.0  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      NaN
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro   25.0    Porto Alegre   4800.0
# 5      Ana   22.0        Salvador   5000.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0

# %% [markdown]
# Exercicio 7

# %%
mediana = data_frame['Idade'].median()
data_frame['Idade'] = data_frame['Idade'].fillna(mediana)
print(data_frame)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria   25.0  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      0.0
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro   25.0    Porto Alegre   4800.0
# 5      Ana   22.0        Salvador   5000.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0

# %% [markdown]
# Exercicio 8

# %%
data_frame['Salário'] = data_frame['Salário'].fillna(data_frame['Idade'])

print(data_frame)
# Out:
#       Nome  Idade          Cidade  Salário
# 0     João   28.0       São Paulo   3500.0
# 1    Maria   25.0  Rio de Janeiro   4500.0
# 2     José   35.0             NaN      0.0
# 3      Ana   22.0        Salvador   5000.0
# 4    Pedro   25.0    Porto Alegre   4800.0
# 5      Ana   22.0        Salvador   5000.0
# 6  Jessica   20.0      são paulo    3410.0
# 7   Carlos   35.0    porto alegre   2500.0

# %% [markdown]
# Exercicio 9

# %%
data_frame['Idade'] = data_frame['Idade'].ffill 
print(data_frame)
# Out:
#       Nome                                              Idade          Cidade  \
# 0     João  <bound method NDFrame.ffill of 0    <bound met...       São Paulo
# 1    Maria  <bound method NDFrame.ffill of 0    <bound met...  Rio de Janeiro
# 2     José  <bound method NDFrame.ffill of 0    <bound met...             NaN
# 3      Ana  <bound method NDFrame.ffill of 0    <bound met...        Salvador
# 4    Pedro  <bound method NDFrame.ffill of 0    <bound met...    Porto Alegre
# 5      Ana  <bound method NDFrame.ffill of 0    <bound met...        Salvador
# 6  Jessica  <bound method NDFrame.ffill of 0    <bound met...      são paulo
# 7   Carlos  <bound method NDFrame.ffill of 0    <bound met...    porto alegre
#
#    Salário
# 0   3500.0
# 1   4500.0
# 2      0.0
# 3   5000.0
# 4   4800.0
# 5   5000.0
# 6   3410.0
# 7   2500.0

# %% [markdown]
# Exercicio 10

# %% [markdown]
# Exercicio 11

# %% [markdown]
# Exercicio 12

# %% [markdown]
# Exercicio 13

# %% [markdown]
# Exercicio 14

# %% [markdown]
# Exercicio 15
